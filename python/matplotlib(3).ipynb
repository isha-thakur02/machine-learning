# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
values = [10,30,40,35,26]
label = ['a','b','c','d','e']
plt.figure(figsize = (6,10))
plt.pie(values, labels = label, shadow = True, explode = [0.2,0,0,0.2,0])
plt.legend()
